# %% [markdown]
# # **Problem Description**

# %% [markdown]
# **Goal:**
# The goal of the problem is to predict whether a passenger was satisfied or not considering his/her overall experience of traveling on the Shinkansen Bullet Train.
#
# **Dataset:**
#
# The problem consists of 2 separate datasets: **Travel data** & Survey **data**. **Travel data** has information related to passengers and attributes related to the Shinkansen train, in which they traveled. The survey data is aggregated data of surveys indicating the post-service experience. You are expected to treat both these datasets as raw data and perform any necessary data cleaning/validation steps as required.
#
# The data has been split into two groups and provided in the Dataset folder. The folder contains both train and test data separately.
#
# Train_Data
# Test_Data
#
# **Target Variable:** Overall_Experience (1 represents ‘satisfied’, and 0 represents ‘not satisfied’)
#
# The **training set** can be used to build your machine learning model. The training set has labels for the target column - Overall_Experience.
#
# The **testing set** should be used to see how well your model performs on unseen data. For the test set, it is expected to predict the ‘Overall_Experience’ level for each participant.

# %% [markdown]
# # **Mounting the drive**

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importing Library

# %%
import pandas as pd
import numpy as np
import numpy as np

from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer

#Importing NN Libraries
from tensorflow.keras.layers import Dense, Input, Dropout, BatchNormalization, Activation, LeakyReLU, ReLU
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras import optimizers

# %% [markdown]
# ### Loading the Data

# %%
# Storing the path of the data file from the Google drive
path = '/content/drive/MyDrive/Hackathon/Datasets/'

# %%
#train_data = pd.read_csv(path+'complete_dataset_training.csv')
train_data = pd.read_csv('complete_dataset_training.csv')

# %%
#test_data = pd.read_csv(path+'complete_dataset_test.csv')
test_data = pd.read_csv('complete_dataset_test.csv')

# %% [markdown]
# ### Understanding the Data

# %%
train_data.head()
# Out:
#    Unnamed: 0          ID  Overall_Experience  Seat_Comfort  Seat_Class  \
# 0           0  98800001.0                 0.0           2.0         0.0
# 1           1  98800002.0                 0.0           3.0         1.0
# 2           2  98800003.0                 1.0           2.0         0.0
# 3           3  98800004.0                 0.0           4.0         1.0
# 4           4  98800005.0                 1.0           4.0         1.0
#
#    Arrival_Time_Convenient  Catering  Platform_Location  Onboard_Wifi_Service  \
# 0                      6.0       6.0                6.0                   5.0
# 1                      6.0       3.0                1.0                   5.0
# 2                      2.0       2.0                1.0                   2.0
# 3                      2.0       4.4                1.0                   4.0
# 4                      4.0       4.0                4.0                   2.0
#
#    Onboard_Entertainment  ...  Cleanliness  Online_Boarding  Gender  \
# 0                    2.0  ...          2.0              3.0     1.0
# 1                    3.0  ...          5.0              5.0     2.0
# 2                    5.0  ...          6.0              6.0     1.0
# 3                    2.0  ...          4.0              4.0     1.0
# 4                    5.0  ...          5.0              5.0     1.0
#
#    Customer_Type   Age  Type_Travel  Travel_Class  Travel_Distance  \
# 0            1.0  52.0          1.8           0.0            272.0
# 1            1.0  48.0          1.0           1.0           2200.0
# 2            1.0  43.0          2.0           0.0           1061.0
# 3            1.0  44.0          2.0           0.0            780.0
# 4            1.0  50.0          2.0           0.0           1981.0
#
#    Departure_Delay_in_Mins  Arrival_Delay_in_Mins
# 0                      0.0                    5.0
# 1                      9.0                    0.0
# 2                     77.0                  119.0
# 3                     13.0                   18.0
# 4                      0.0                    0.0
#
# [5 rows x 26 columns]

# %%
train_data.tail()
# Out:
#        Unnamed: 0          ID  Overall_Experience  Seat_Comfort  Seat_Class  \
# 53662       53662  98853663.0                 0.0           5.0         0.0
# 53663       53663  98853664.0                 1.0           2.0         1.0
# 53664       53664  98853665.0                 1.0           6.0         0.0
# 53665       53665  98853666.0                 0.0           2.0         1.0
# 53666       53666  98853667.0                 1.0           3.0         0.0
#
#        Arrival_Time_Convenient  Catering  Platform_Location  \
# 53662                      6.0       5.0                5.0
# 53663                      2.0       2.0                1.0
# 53664                      4.0       4.0                4.0
# 53665                      2.0       2.0                4.0
# 53666                      3.0       6.0                3.0
#
#        Onboard_Wifi_Service  Onboard_Entertainment  ...  Cleanliness  \
# 53662                   6.0                    5.0  ...          5.0
# 53663                   6.0                    6.0  ...          5.0
# 53664                   6.0                    6.0  ...          4.0
# 53665                   3.0                    2.0  ...          5.0
# 53666                   6.0                    NaN  ...          NaN
#
#        Online_Boarding  Gender  Customer_Type   Age  Type_Travel  \
# 53662              6.0     2.0            1.0  33.0          1.0
# 53663              4.0     2.0            1.0  41.0          2.0
# 53664              6.0     2.0            1.0  41.0          2.0
# 53665              3.0     2.0            2.0  30.0          2.0
# 53666              NaN     NaN            NaN   NaN          NaN
#
#        Travel_Class  Travel_Distance  Departure_Delay_in_Mins  \
# 53662           1.0           2146.0                      0.0
# 53663           0.0            364.0                      1.0
# 53664           1.0           1377.0                     38.0
# 53665           0.0           1889.0                     75.0
# 53666           NaN              NaN                      NaN
#
#        Arrival_Delay_in_Mins
# 53662                    0.0
# 53663                    0.0
# 53664                   17.0
# 53665                   74.0
# 53666                    NaN
#
# [5 rows x 26 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53667 entries, 0 to 53666
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               53667 non-null  int64
#  1   ID                       53667 non-null  float64
#  2   Overall_Experience       53667 non-null  float64
#  3   Seat_Comfort             53667 non-null  float64
#  4   Seat_Class               53667 non-null  float64
#  5   Arrival_Time_Convenient  53667 non-null  float64
#  6   Catering                 53667 non-null  float64
#  7   Platform_Location        53667 non-null  float64
#  8   Onboard_Wifi_Service     53667 non-null  float64
#  9   Onboard_Entertainment    53666 non-null  float64
#  10  Online_Support           53666 non-null  float64
#  11  Ease_of_Online_Booking   53666 non-null  float64
#  12  Onboard_Service          53666 non-null  float64
#  13  Legroom                  53666 non-null  float64
#  14  Baggage_Handling         53666 non-null  float64
#  15  CheckIn_Service          53666 non-null  float64
#  16  Cleanliness              53666 non-null  float64
#  17  Online_Boarding          53666 non-null  float64
#  18  Gender                   53666 non-null  float64
#  19  Customer_Type            53666 non-null  float64
#  20  Age                      53666 non-null  float64
#  21  Type_Travel              53666 non-null  float64
#  22  Travel_Class             53666 non-null  float64
#  23  Travel_Distance          53666 non-null  float64
#  24  Departure_Delay_in_Mins  53666 non-null  float64
#  25  Arrival_Delay_in_Mins    53666 non-null  float64
# dtypes: float64(25), int64(1)
# memory usage: 10.6 MB

# %%
train_data.describe().T
# Out:
#                            count          mean           std         min  \
# Unnamed: 0               53667.0  2.683300e+04  15492.472785         0.0
# ID                       53667.0  9.882683e+07  15492.472785  98800001.0
# Overall_Experience       53667.0  5.460711e-01      0.497878         0.0
# Seat_Comfort             53667.0  3.772713e+00      1.447433         1.0
# Seat_Class               53667.0  4.975497e-01      0.499999         0.0
# Arrival_Time_Convenient  53667.0  3.981396e+00      1.481592         1.0
# Catering                 53667.0  3.800995e+00      1.430309         1.0
# Platform_Location        53667.0  3.782656e+00      1.631750         1.0
# Onboard_Wifi_Service     53667.0  4.158090e+00      1.436495         1.0
# Onboard_Entertainment    53666.0  4.321884e+00      1.423301         1.0
# Online_Support           53666.0  4.498118e+00      1.343172         1.0
# Ease_of_Online_Booking   53666.0  4.422103e+00      1.375250         1.0
# Onboard_Service          53666.0  4.441755e+00      1.271587         1.0
# Legroom                  53666.0  4.402918e+00      1.405709         1.0
# Baggage_Handling         53666.0  4.650911e+00      1.233734         2.0
# CheckIn_Service          53666.0  4.343372e+00      1.262308         1.0
# Cleanliness              53666.0  4.658163e+00      1.232366         1.0
# Online_Boarding          53666.0  4.331212e+00      1.328935         1.0
# Gender                   53666.0  1.493020e+00      0.499790         1.0
# Customer_Type            53666.0  1.182708e+00      0.372442         1.0
# Age                      53666.0  3.943964e+01     15.095273         7.0
# Type_Travel              53666.0  1.688186e+00      0.445552         1.0
# Travel_Class             53666.0  5.215220e-01      0.499541         0.0
# Travel_Distance          53666.0  1.978769e+03   1029.012754        50.0
# Departure_Delay_in_Mins  53666.0  1.475437e+01     38.634208         0.0
# Arrival_Delay_in_Mins    53666.0  1.507105e+01     38.860319         0.0
#
#                                 25%         50%         75%         max
# Unnamed: 0                  13416.5     26833.0     40249.5     53666.0
# ID                       98813417.5  98826834.0  98840250.5  98853667.0
# Overall_Experience              0.0         1.0         1.0         1.0
# Seat_Comfort                    2.0         4.0         5.0         6.0
# Seat_Class                      0.0         0.0         1.0         1.0
# Arrival_Time_Convenient         3.0         4.0         5.0         6.0
# Catering                        3.0         4.0         5.0         6.0
# Platform_Location               3.0         4.0         5.0         6.0
# Onboard_Wifi_Service            3.0         4.0         5.0         6.0
# Onboard_Entertainment           3.0         5.0         5.0         6.0
# Online_Support                  4.0         5.0         6.0         6.0
# Ease_of_Online_Booking          3.0         5.0         6.0         6.0
# Onboard_Service                 4.0         5.0         5.0         6.0
# Legroom                         3.0         5.0         6.0         6.0
# Baggage_Handling                4.0         5.0         6.0         6.0
# CheckIn_Service                 4.0         4.0         5.0         6.0
# Cleanliness                     4.0         5.0         6.0         6.0
# Online_Boarding                 3.0         5.0         5.0         6.0
# Gender                          1.0         1.0         2.0         2.0
# Customer_Type                   1.0         1.0         1.0         2.0
# Age                            27.0        40.0        51.0        85.0
# Type_Travel                     1.0         2.0         2.0         2.0
# Travel_Class                    0.0         1.0         1.0         1.0
# Travel_Distance              1359.0      1922.0      2536.0      6951.0
# Departure_Delay_in_Mins         0.0         0.0        12.0      1592.0
# Arrival_Delay_in_Mins           0.0         0.0        13.0      1584.0

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35602 entries, 0 to 35601
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               35602 non-null  int64
#  1   ID                       35602 non-null  float64
#  2   Seat_Comfort             35602 non-null  float64
#  3   Seat_Class               35602 non-null  float64
#  4   Arrival_Time_Convenient  35602 non-null  float64
#  5   Catering                 35602 non-null  float64
#  6   Platform_Location        35602 non-null  float64
#  7   Onboard_Wifi_Service     35602 non-null  float64
#  8   Onboard_Entertainment    35602 non-null  float64
#  9   Online_Support           35602 non-null  float64
#  10  Ease_of_Online_Booking   35602 non-null  float64
#  11  Onboard_Service          35602 non-null  float64
#  12  Legroom                  35602 non-null  float64
#  13  Baggage_Handling         35602 non-null  float64
#  14  CheckIn_Service          35602 non-null  float64
#  15  Cleanliness              35602 non-null  float64
#  16  Online_Boarding          35602 non-null  float64
#  17  Gender                   35602 non-null  float64
#  18  Customer_Type            35602 non-null  float64
#  19  Age                      35602 non-null  float64
#  20  Type_Travel              35602 non-null  float64
#  21  Travel_Class             35602 non-null  float64
#  22  Travel_Distance          35602 non-null  float64
#  23  Departure_Delay_in_Mins  35602 non-null  float64
#  24  Arrival_Delay_in_Mins    35602 non-null  float64
# dtypes: float64(24), int64(1)
# memory usage: 6.8 MB

# %%
# Split the data into features and target variable
X = train_data.drop(['ID', 'Overall_Experience', 'Unnamed: 0'], axis=1)
y = train_data['Overall_Experience']

# %%
X.head()
# Out:
#    Seat_Comfort  Seat_Class  Arrival_Time_Convenient  Catering  \
# 0           2.0         0.0                      6.0       6.0
# 1           3.0         1.0                      6.0       3.0
# 2           2.0         0.0                      2.0       2.0
# 3           4.0         1.0                      2.0       4.4
# 4           4.0         1.0                      4.0       4.0
#
#    Platform_Location  Onboard_Wifi_Service  Onboard_Entertainment  \
# 0                6.0                   5.0                    2.0
# 1                1.0                   5.0                    3.0
# 2                1.0                   2.0                    5.0
# 3                1.0                   4.0                    2.0
# 4                4.0                   2.0                    5.0
#
#    Online_Support  Ease_of_Online_Booking  Onboard_Service  ...  Cleanliness  \
# 0             4.0                     2.0              2.0  ...          2.0
# 1             5.0                     5.0              6.0  ...          5.0
# 2             6.0                     6.0              6.0  ...          6.0
# 3             4.0                     4.0              4.0  ...          4.0
# 4             6.0                     5.0              5.0  ...          5.0
#
#    Online_Boarding  Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# 0              3.0     1.0            1.0  52.0          1.8           0.0
# 1              5.0     2.0            1.0  48.0          1.0           1.0
# 2              6.0     1.0            1.0  43.0          2.0           0.0
# 3              4.0     1.0            1.0  44.0          2.0           0.0
# 4              5.0     1.0            1.0  50.0          2.0           0.0
#
#    Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins
# 0            272.0                      0.0                    5.0
# 1           2200.0                      9.0                    0.0
# 2           1061.0                     77.0                  119.0
# 3            780.0                     13.0                   18.0
# 4           1981.0                      0.0                    0.0
#
# [5 rows x 23 columns]

# %% [markdown]
# # **Building the NN Architecture**

# %% [markdown]
# **MODEL 1**

# %%
# Define the neural network architecture
model1 = Sequential()

#1st Fully connected layer
model1.add(Dense(64, activation='relu', input_shape=(X.shape[1],)))
model1.add(BatchNormalization())
model1.add(Dropout(0.5))

# 2nd fully connected layer
model1.add(Dense(32, activation='relu'))
model1.add(BatchNormalization())
model1.add(Dropout(0.5))

# Final dense layer
model1.add(Dense(1, activation='sigmoid'))

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1536
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,033
# Trainable params: 3,841
# Non-trainable params: 192
# _________________________________________________________________

# %%
# Compile the model
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # **Training the Model**

# %%
# Train the model
model1.fit(X, y, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 1342/1342 [==============================] - 12s 5ms/step - loss: 0.6520 - accuracy: 0.6560 - val_loss: nan - val_accuracy: 0.8059
# Epoch 2/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4894 - accuracy: 0.7732 - val_loss: nan - val_accuracy: 0.8227
# Epoch 3/20
# 1342/1342 [==============================] - 6s 5ms/step - loss: 0.4630 - accuracy: 0.7904 - val_loss: nan - val_accuracy: 0.8075
# Epoch 4/20
# 1342/1342 [==============================] - 7s 6ms/step - loss: 0.4495 - accuracy: 0.8041 - val_loss: nan - val_accuracy: 0.8303
# Epoch 5/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4415 - accuracy: 0.8052 - val_loss: nan - val_accuracy: 0.8222
# Epoch 6/20
# 1342/1342 [==============================] - 7s 6ms/step - loss: 0.4353 - accuracy: 0.8104 - val_loss: nan - val_accuracy: 0.8314
# Epoch 7/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4329 - accuracy: 0.8130 - val_loss: nan - val_accuracy: 0.8319
# Epoch 8/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4323 - accuracy: 0.8142 - val_loss: nan - val_accuracy: 0.8261
# Epoch 9/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4297 - accuracy: 0.8143 - val_loss: nan - val_accuracy: 0.8326
# Epoch 10/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4261 - accuracy: 0.8165 - val_loss: nan - val_accuracy: 0.8357
# Epoch 11/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4226 - accuracy: 0.8193 - val_loss: nan - val_accuracy: 0.8236
# Epoch 12/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4228 - accuracy: 0.8196 - val_loss: nan - val_accuracy: 0.8379
# Epoch 13/20
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.4192 - accuracy: 0.8211 - val_loss: nan - val_accuracy: 0.7208
# Epoch 14/20
# 1342/1342 [==============================] - 7s 6ms/step - loss: 0.4126 - accuracy: 0.8264 - val_loss: nan - val_accuracy: 0.8448
# Epoch 15/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4137 - accuracy: 0.8249 - val_loss: nan - val_accuracy: 0.8331
# Epoch 16/20
# 1342/1342 [==============================] - 6s 5ms/step - loss: 0.4090 - accuracy: 0.8269 - val_loss: nan - val_accuracy: 0.8482
# Epoch 17/20
# 1342/1342 [==============================] - 7s 6ms/step - loss: 0.4105 - accuracy: 0.8261 - val_loss: nan - val_accuracy: 0.8449
# Epoch 18/20
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4060 - accuracy: 0.8297 - val_loss: nan - val_accuracy: 0.8318
# Epoch 19/20
# 1342/1342 [==============================] - 7s 6ms/step - loss: 0.4030 - accuracy: 0.8305 - val_loss: nan - val_accuracy: 0.7713
# Epoch 20/20
# 1342/1342 [==============================] - 6s 5ms/step - loss: 0.3988 - accuracy: 0.8326 - val_loss: nan - val_accuracy: 0.8429

# %%
# Preprocess the test data
X_test = test_data.drop(['ID','Unnamed: 0'], axis=1)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35602 entries, 0 to 35601
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Seat_Comfort             35602 non-null  float64
#  1   Seat_Class               35602 non-null  float64
#  2   Arrival_Time_Convenient  35602 non-null  float64
#  3   Catering                 35602 non-null  float64
#  4   Platform_Location        35602 non-null  float64
#  5   Onboard_Wifi_Service     35602 non-null  float64
#  6   Onboard_Entertainment    35602 non-null  float64
#  7   Online_Support           35602 non-null  float64
#  8   Ease_of_Online_Booking   35602 non-null  float64
#  9   Onboard_Service          35602 non-null  float64
#  10  Legroom                  35602 non-null  float64
#  11  Baggage_Handling         35602 non-null  float64
#  12  CheckIn_Service          35602 non-null  float64
#  13  Cleanliness              35602 non-null  float64
#  14  Online_Boarding          35602 non-null  float64
#  15  Gender                   35602 non-null  float64
#  16  Customer_Type            35602 non-null  float64
#  17  Age                      35602 non-null  float64
#  18  Type_Travel              35602 non-null  float64
#  19  Travel_Class             35602 non-null  float64
#  20  Travel_Distance          35602 non-null  float64
#  21  Departure_Delay_in_Mins  35602 non-null  float64
#  22  Arrival_Delay_in_Mins    35602 non-null  float64
# dtypes: float64(23)
# memory usage: 6.2 MB

# %%
X_test.head()
# Out:
#    Seat_Comfort  Seat_Class  Arrival_Time_Convenient  Catering  \
# 0           4.0         0.0                      4.0       4.0
# 1           1.0         1.0                      5.0       3.0
# 2           6.0         1.0                      6.0       6.0
# 3           4.0         0.0                      6.0       4.0
# 4           6.0         1.0                      1.0       6.0
#
#    Platform_Location  Onboard_Wifi_Service  Onboard_Entertainment  \
# 0                4.0                   2.0                    6.0
# 1                4.0                   4.0                    3.0
# 2                6.0                   6.0                    6.0
# 3                6.0                   3.0                    4.0
# 4                1.0                   6.0                    6.0
#
#    Online_Support  Ease_of_Online_Booking  Onboard_Service  ...  Cleanliness  \
# 0             5.0                     6.0              6.0  ...          6.0
# 1             4.0                     4.0              6.0  ...          6.0
# 2             6.0                     2.0              2.0  ...          2.0
# 3             6.0                     3.0              4.0  ...          6.0
# 4             6.0                     6.0              5.0  ...          6.0
#
#    Online_Boarding  Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# 0              3.0     1.0            1.0  36.0          2.0           0.0
# 1              4.0     1.0            2.0  21.0          2.0           0.0
# 2              6.0     2.0            1.0  60.0          2.0           0.0
# 3              3.0     1.0            1.0  29.0          1.0           1.0
# 4              6.0     2.0            2.0  18.0          2.0           0.0
#
#    Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins
# 0            532.0                      0.0                    0.0
# 1           1425.0                      9.0                   28.0
# 2           2832.0                      0.0                    0.0
# 3           1352.0                      0.0                    0.0
# 4           1610.0                     17.0                    0.0
#
# [5 rows x 23 columns]

# %%
# Make predictions on the test data
y_pred = model1.predict(X_test)
# Out:
# 1113/1113 [==============================] - 2s 2ms/step

# %%
# Convert predictions to binary labels
y_pred = np.round(y_pred)

# %%
print(y_pred)
# Out:
# [[1.]
#  [0.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [0.]]

# %%
print(test_data['ID'].shape)
# Out:
# (35602,)

# %%
print(y_pred.flatten().shape)
# Out:
# (35602,)

# %%
# Save the predictions to a CSV file
# note that y_pred is a 2D array, so we need to flatten it to convert to 1D
predictions = pd.DataFrame({'ID': test_data['ID'], 'Overall_Experience': y_pred.flatten().astype(int)})
#predictions.to_csv(path+'predictions.csv', index=False)
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# **MODEL 2**

# %%
# Define the neural network architecture
model2 = Sequential()

#1st Fully connected layer
model2.add(Dense(128, activation='relu', input_shape=(X.shape[1],)))
model2.add(BatchNormalization())
model2.add(Dropout(0.2))

# 2nd fully connected layer
model2.add(Dense(64, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.2))

# 2nd fully connected layer
model2.add(Dense(32, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.2))

# Final dense layer
model2.add(Dense(1, activation='sigmoid'))

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               3072
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 14,337
# Trainable params: 13,889
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# # **Compiling and training the model**

# %%
# Compile the model
learning_rate = 0.001
optimizer = optimizers.Adam(learning_rate=learning_rate)
model2.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model2.fit(X, y, epochs=25, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/25
# 1342/1342 [==============================] - 12s 6ms/step - loss: 0.5372 - accuracy: 0.7345 - val_loss: nan - val_accuracy: 0.6566
# Epoch 2/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.4436 - accuracy: 0.8027 - val_loss: nan - val_accuracy: 0.8320
# Epoch 3/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.4205 - accuracy: 0.8194 - val_loss: nan - val_accuracy: 0.8334
# Epoch 4/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.4162 - accuracy: 0.8211 - val_loss: nan - val_accuracy: 0.8249
# Epoch 5/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.4099 - accuracy: 0.8224 - val_loss: nan - val_accuracy: 0.8175
# Epoch 6/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.4024 - accuracy: 0.8270 - val_loss: nan - val_accuracy: 0.8305
# Epoch 7/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.3917 - accuracy: 0.8312 - val_loss: nan - val_accuracy: 0.8540
# Epoch 8/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3810 - accuracy: 0.8364 - val_loss: nan - val_accuracy: 0.8470
# Epoch 9/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3804 - accuracy: 0.8392 - val_loss: nan - val_accuracy: 0.8239
# Epoch 10/25
# 1342/1342 [==============================] - 9s 7ms/step - loss: 0.3795 - accuracy: 0.8389 - val_loss: nan - val_accuracy: 0.8276
# Epoch 11/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3736 - accuracy: 0.8411 - val_loss: nan - val_accuracy: 0.8522
# Epoch 12/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.3768 - accuracy: 0.8402 - val_loss: nan - val_accuracy: 0.7936
# Epoch 13/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3697 - accuracy: 0.8399 - val_loss: nan - val_accuracy: 0.8585
# Epoch 14/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3656 - accuracy: 0.8454 - val_loss: nan - val_accuracy: 0.7301
# Epoch 15/25
# 1342/1342 [==============================] - 9s 7ms/step - loss: 0.3645 - accuracy: 0.8435 - val_loss: nan - val_accuracy: 0.8011
# Epoch 16/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.3691 - accuracy: 0.8426 - val_loss: nan - val_accuracy: 0.7494
# Epoch 17/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3660 - accuracy: 0.8413 - val_loss: nan - val_accuracy: 0.8625
# Epoch 18/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.3675 - accuracy: 0.8398 - val_loss: nan - val_accuracy: 0.8599
# Epoch 19/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3676 - accuracy: 0.8412 - val_loss: nan - val_accuracy: 0.8531
# Epoch 20/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3582 - accuracy: 0.8465 - val_loss: nan - val_accuracy: 0.8531
# Epoch 21/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.3533 - accuracy: 0.8481 - val_loss: nan - val_accuracy: 0.8703
# Epoch 22/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3477 - accuracy: 0.8498 - val_loss: nan - val_accuracy: 0.8720
# Epoch 23/25
# 1342/1342 [==============================] - 9s 7ms/step - loss: 0.3464 - accuracy: 0.8519 - val_loss: nan - val_accuracy: 0.8242
# Epoch 24/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.3407 - accuracy: 0.8540 - val_loss: nan - val_accuracy: 0.8536
# Epoch 25/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3413 - accuracy: 0.8538 - val_loss: nan - val_accuracy: 0.8623

# %%
# Make predictions on the test data
y_pred = model2.predict(X_test)

# Convert predictions to binary labels
y_pred = np.round(y_pred)
# Out:
# 1113/1113 [==============================] - 2s 2ms/step

# %%
# Save the predictions to a CSV file
predictions = pd.DataFrame({'ID': test_data['ID'], 'Overall_Experience': y_pred.flatten().astype(int)})
#predictions.to_csv(path+'predictions2.csv', index=False)
predictions.to_csv('predictions2.csv', index=False)

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# # Model 3

# %%
# Define the neural network architecture
model3 = Sequential()

#1st Fully connected layer
model3.add(Dense(128, activation='relu', input_shape=(X.shape[1],)))
model3.add(BatchNormalization())
model3.add(Dropout(0.2))

# 2nd fully connected layer
model3.add(Dense(64, activation='relu'))
model3.add(Dense(64, activation='relu'))

# 2nd fully connected layer
model3.add(Dense(32, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.2))

# Final dense layer
model3.add(Dense(1, activation='sigmoid'))

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 128)               3072
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  batch_normalization_6 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 18,241
# Trainable params: 17,921
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# # **Compiling and training the model**

# %%
# Compile the model
learning_rate = 0.002
optimizer = optimizers.Adam(learning_rate=learning_rate)
model3.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model3.fit(X, y, epochs=25, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/25
# 1342/1342 [==============================] - 10s 5ms/step - loss: 0.5078 - accuracy: 0.7499 - val_loss: nan - val_accuracy: 0.8195
# Epoch 2/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.4244 - accuracy: 0.8152 - val_loss: nan - val_accuracy: 0.8157
# Epoch 3/25
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.4152 - accuracy: 0.8186 - val_loss: nan - val_accuracy: 0.8247
# Epoch 4/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.4069 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8039
# Epoch 5/25
# 1342/1342 [==============================] - 7s 6ms/step - loss: 0.3996 - accuracy: 0.8281 - val_loss: nan - val_accuracy: 0.7941
# Epoch 6/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3937 - accuracy: 0.8317 - val_loss: nan - val_accuracy: 0.8533
# Epoch 7/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3851 - accuracy: 0.8353 - val_loss: nan - val_accuracy: 0.5887
# Epoch 8/25
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.3821 - accuracy: 0.8378 - val_loss: nan - val_accuracy: 0.7663
# Epoch 9/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3870 - accuracy: 0.8343 - val_loss: nan - val_accuracy: 0.8329
# Epoch 10/25
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.3737 - accuracy: 0.8401 - val_loss: nan - val_accuracy: 0.8406
# Epoch 11/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3748 - accuracy: 0.8405 - val_loss: nan - val_accuracy: 0.8576
# Epoch 12/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3727 - accuracy: 0.8411 - val_loss: nan - val_accuracy: 0.8555
# Epoch 13/25
# 1342/1342 [==============================] - 7s 6ms/step - loss: 0.3696 - accuracy: 0.8421 - val_loss: nan - val_accuracy: 0.8590
# Epoch 14/25
# 1342/1342 [==============================] - 9s 7ms/step - loss: 0.3699 - accuracy: 0.8425 - val_loss: nan - val_accuracy: 0.8349
# Epoch 15/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3634 - accuracy: 0.8442 - val_loss: nan - val_accuracy: 0.8084
# Epoch 16/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3599 - accuracy: 0.8468 - val_loss: nan - val_accuracy: 0.8212
# Epoch 17/25
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.3530 - accuracy: 0.8481 - val_loss: nan - val_accuracy: 0.7617
# Epoch 18/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3457 - accuracy: 0.8517 - val_loss: nan - val_accuracy: 0.8258
# Epoch 19/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3433 - accuracy: 0.8526 - val_loss: nan - val_accuracy: 0.8611
# Epoch 20/25
# 1342/1342 [==============================] - 7s 6ms/step - loss: 0.3369 - accuracy: 0.8558 - val_loss: nan - val_accuracy: 0.7990
# Epoch 21/25
# 1342/1342 [==============================] - 9s 6ms/step - loss: 0.3282 - accuracy: 0.8579 - val_loss: nan - val_accuracy: 0.8320
# Epoch 22/25
# 1342/1342 [==============================] - 7s 5ms/step - loss: 0.3354 - accuracy: 0.8566 - val_loss: nan - val_accuracy: 0.8632
# Epoch 23/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3274 - accuracy: 0.8594 - val_loss: nan - val_accuracy: 0.8418
# Epoch 24/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3223 - accuracy: 0.8614 - val_loss: nan - val_accuracy: 0.8745
# Epoch 25/25
# 1342/1342 [==============================] - 8s 6ms/step - loss: 0.3199 - accuracy: 0.8630 - val_loss: nan - val_accuracy: 0.7875

# %%
# Make predictions on the test data
y_pred = model3.predict(X_test)

# Convert predictions to binary labels
y_pred = np.round(y_pred)
# Out:
# 1113/1113 [==============================] - 2s 2ms/step

# %%
# Save the predictions to a CSV file
predictions = pd.DataFrame({'ID': test_data['ID'], 'Overall_Experience': y_pred.flatten().astype(int)})
#predictions.to_csv(path+'predictions2.csv', index=False)
predictions.to_csv('predictions3.csv', index=False)

# %% [markdown]
# # Model 4

# %%
# Define the neural network architecture
model4 = Sequential()

#1st Fully connected layer
model4.add(Dense(128, activation='relu', input_shape=(X.shape[1],)))
model4.add(BatchNormalization())
model4.add(Dropout(0.2))

# 2nd fully connected layer
model4.add(Dense(64, activation='relu'))
model4.add(Dense(64, activation='linear'))
model4.add(Dense(48, activation='relu'))
model4.add(Dropout(0.2))

# 2nd fully connected layer
model4.add(Dense(32, activation='relu'))
model4.add(BatchNormalization())
model4.add(Dropout(0.2))

model4.add(Dense(48, activation='relu'))
model4.add(BatchNormalization())
model4.add(Dropout(0.2))

# Final dense layer
model4.add(Dense(1, activation='sigmoid'))

# %%
model4.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 128)               3072
#
#  batch_normalization_14 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 64)                8256
#
#  dense_28 (Dense)            (None, 64)                4160
#
#  dense_29 (Dense)            (None, 48)                3120
#
#  dropout_15 (Dropout)        (None, 48)                0
#
#  dense_30 (Dense)            (None, 32)                1568
#
#  batch_normalization_15 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 32)                0
#
#  dense_31 (Dense)            (None, 48)                1584
#
#  batch_normalization_16 (Bat  (None, 48)               192
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 48)                0
#
#  dense_32 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 22,641
# Trainable params: 22,225
# Non-trainable params: 416
# _________________________________________________________________

# %% [markdown]
# # **Compiling and training the model**

# %%
# Compile the model
learning_rate = 0.002
optimizer = optimizers.Adam(learning_rate=learning_rate)
model4.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model4.fit(X, y, epochs=25, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/25
# 1342/1342 [==============================] - 15s 8ms/step - loss: 0.5688 - accuracy: 0.6999 - val_loss: nan - val_accuracy: 0.7253
# Epoch 2/25
# 1342/1342 [==============================] - 11s 8ms/step - loss: 0.4423 - accuracy: 0.8038 - val_loss: nan - val_accuracy: 0.8230
# Epoch 3/25
# 1342/1342 [==============================] - 11s 8ms/step - loss: 0.4273 - accuracy: 0.8148 - val_loss: nan - val_accuracy: 0.8238
# Epoch 4/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.4161 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.7904
# Epoch 5/25
# 1342/1342 [==============================] - 10s 8ms/step - loss: 0.4023 - accuracy: 0.8278 - val_loss: nan - val_accuracy: 0.7865
# Epoch 6/25
# 1342/1342 [==============================] - 10s 8ms/step - loss: 0.3978 - accuracy: 0.8299 - val_loss: nan - val_accuracy: 0.8531
# Epoch 7/25
# 1342/1342 [==============================] - 11s 9ms/step - loss: 0.3916 - accuracy: 0.8333 - val_loss: nan - val_accuracy: 0.8374
# Epoch 8/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3815 - accuracy: 0.8375 - val_loss: nan - val_accuracy: 0.7969
# Epoch 9/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3830 - accuracy: 0.8353 - val_loss: nan - val_accuracy: 0.7457
# Epoch 10/25
# 1342/1342 [==============================] - 10s 8ms/step - loss: 0.3736 - accuracy: 0.8399 - val_loss: nan - val_accuracy: 0.8556
# Epoch 11/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3653 - accuracy: 0.8434 - val_loss: nan - val_accuracy: 0.8395
# Epoch 12/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3519 - accuracy: 0.8494 - val_loss: nan - val_accuracy: 0.8791
# Epoch 13/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3460 - accuracy: 0.8527 - val_loss: nan - val_accuracy: 0.8739
# Epoch 14/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3390 - accuracy: 0.8557 - val_loss: nan - val_accuracy: 0.8680
# Epoch 15/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3326 - accuracy: 0.8594 - val_loss: nan - val_accuracy: 0.8650
# Epoch 16/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3293 - accuracy: 0.8580 - val_loss: nan - val_accuracy: 0.8392
# Epoch 17/25
# 1342/1342 [==============================] - 9s 7ms/step - loss: 0.3266 - accuracy: 0.8612 - val_loss: nan - val_accuracy: 0.8834
# Epoch 18/25
# 1342/1342 [==============================] - 10s 8ms/step - loss: 0.3243 - accuracy: 0.8618 - val_loss: nan - val_accuracy: 0.8614
# Epoch 19/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3260 - accuracy: 0.8619 - val_loss: nan - val_accuracy: 0.8438
# Epoch 20/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3206 - accuracy: 0.8646 - val_loss: nan - val_accuracy: 0.8790
# Epoch 21/25
# 1342/1342 [==============================] - 9s 7ms/step - loss: 0.3213 - accuracy: 0.8626 - val_loss: nan - val_accuracy: 0.8561
# Epoch 22/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3212 - accuracy: 0.8604 - val_loss: nan - val_accuracy: 0.8890
# Epoch 23/25
# 1342/1342 [==============================] - 11s 8ms/step - loss: 0.3207 - accuracy: 0.8627 - val_loss: nan - val_accuracy: 0.8753
# Epoch 24/25
# 1342/1342 [==============================] - 10s 7ms/step - loss: 0.3194 - accuracy: 0.8612 - val_loss: nan - val_accuracy: 0.8728
# Epoch 25/25
# 1342/1342 [==============================] - 9s 7ms/step - loss: 0.3125 - accuracy: 0.8626 - val_loss: nan - val_accuracy: 0.8588

# %%
# Make predictions on the test data
y_pred = model4.predict(X_test)

# Convert predictions to binary labels
y_pred = np.round(y_pred)
# Out:
# 1113/1113 [==============================] - 2s 2ms/step

# %%
# Save the predictions to a CSV file
predictions = pd.DataFrame({'ID': test_data['ID'], 'Overall_Experience': y_pred.flatten().astype(int)})
#predictions.to_csv(path+'predictions2.csv', index=False)
predictions.to_csv('predictions4.csv', index=False)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
X.isnull().sum()
# Out:
# Seat_Comfort               0
# Seat_Class                 0
# Arrival_Time_Convenient    0
# Catering                   0
# Platform_Location          0
# Onboard_Wifi_Service       0
# Onboard_Entertainment      1
# Online_Support             1
# Ease_of_Online_Booking     1
# Onboard_Service            1
# Legroom                    1
# Baggage_Handling           1
# CheckIn_Service            1
# Cleanliness                1
# Online_Boarding            1
# Gender                     1
# Customer_Type              1
# Age                        1
# Type_Travel                1
# Travel_Class               1
# Travel_Distance            1
# Departure_Delay_in_Mins    1
# Arrival_Delay_in_Mins      1
# dtype: int64

# %%
test_x = X_test.copy()
test_x.drop(columns=["Departure_Delay_in_Mins","Arrival_Delay_in_Mins"], axis=1, inplace=True)

# %%
trial_data = pd.read_csv("complete_dataset_training.csv", index_col=0)
trial_data.isnull().sum()
# Out:
# ID                         0
# Overall_Experience         0
# Seat_Comfort               0
# Seat_Class                 0
# Arrival_Time_Convenient    0
# Catering                   0
# Platform_Location          0
# Onboard_Wifi_Service       0
# Onboard_Entertainment      0
# Online_Support             0
# Ease_of_Online_Booking     0
# Onboard_Service            0
# Legroom                    0
# Baggage_Handling           0
# CheckIn_Service            0
# Cleanliness                0
# Online_Boarding            0
# Gender                     0
# Customer_Type              0
# Age                        0
# Type_Travel                0
# Travel_Class               0
# Travel_Distance            0
# Departure_Delay_in_Mins    0
# Arrival_Delay_in_Mins      0
# dtype: int64

# %%
y = trial_data["Overall_Experience"]
trial_data.drop(columns=["ID", "Departure_Delay_in_Mins", "Overall_Experience", "Arrival_Delay_in_Mins"], axis=1, inplace=True)

# %%
trial_data.head()
# Out:
#    Seat_Comfort  Seat_Class  Arrival_Time_Convenient  Catering  \
# 0           2.0         0.0                      6.0       6.0
# 1           3.0         1.0                      6.0       3.0
# 2           2.0         0.0                      2.0       2.0
# 3           4.0         1.0                      2.0       4.4
# 4           4.0         1.0                      4.0       4.0
#
#    Platform_Location  Onboard_Wifi_Service  Onboard_Entertainment  \
# 0                6.0                   5.0                    2.0
# 1                1.0                   5.0                    3.0
# 2                1.0                   2.0                    5.0
# 3                1.0                   4.0                    2.0
# 4                4.0                   2.0                    5.0
#
#    Online_Support  Ease_of_Online_Booking  Onboard_Service  ...  \
# 0             4.0                     2.0              2.0  ...
# 1             5.0                     5.0              6.0  ...
# 2             6.0                     6.0              6.0  ...
# 3             4.0                     4.0              4.0  ...
# 4             6.0                     5.0              5.0  ...
#
#    Baggage_Handling  CheckIn_Service  Cleanliness  Online_Boarding  Gender  \
# 0               2.0              5.0          2.0              3.0     1.0
# 1               3.0              2.0          5.0              5.0     2.0
# 2               6.0              5.0          6.0              6.0     1.0
# 3               4.0              5.0          4.0              4.0     1.0
# 4               5.0              5.0          5.0              5.0     1.0
#
#    Customer_Type   Age  Type_Travel  Travel_Class  Travel_Distance
# 0            1.0  52.0          1.8           0.0            272.0
# 1            1.0  48.0          1.0           1.0           2200.0
# 2            1.0  43.0          2.0           0.0           1061.0
# 3            1.0  44.0          2.0           0.0            780.0
# 4            1.0  50.0          2.0           0.0           1981.0
#
# [5 rows x 21 columns]

# %%
knn_tuned = KNeighborsClassifier(n_neighbors=6)
knn_tuned.fit(trial_data, y)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
y_pred = knn_tuned.predict(test_x)
y_pred = np.round(y_pred)

# %%
# Save the predictions to a CSV file
predictions = pd.DataFrame({'ID': test_data['ID'], 'Overall_Experience': y_pred.flatten().astype(int)})
#predictions.to_csv(path+'predictions2.csv', index=False)
predictions.to_csv('predictions5.csv', index=False)

# %%
trial_data.head()
# Out:
#    Seat_Comfort  Seat_Class  Arrival_Time_Convenient  Catering  \
# 0           2.0         0.0                      6.0       6.0
# 1           3.0         1.0                      6.0       3.0
# 2           2.0         0.0                      2.0       2.0
# 3           4.0         1.0                      2.0       4.4
# 4           4.0         1.0                      4.0       4.0
#
#    Platform_Location  Onboard_Wifi_Service  Onboard_Entertainment  \
# 0                6.0                   5.0                    2.0
# 1                1.0                   5.0                    3.0
# 2                1.0                   2.0                    5.0
# 3                1.0                   4.0                    2.0
# 4                4.0                   2.0                    5.0
#
#    Online_Support  Ease_of_Online_Booking  Onboard_Service  ...  \
# 0             4.0                     2.0              2.0  ...
# 1             5.0                     5.0              6.0  ...
# 2             6.0                     6.0              6.0  ...
# 3             4.0                     4.0              4.0  ...
# 4             6.0                     5.0              5.0  ...
#
#    Baggage_Handling  CheckIn_Service  Cleanliness  Online_Boarding  Gender  \
# 0               2.0              5.0          2.0              3.0     1.0
# 1               3.0              2.0          5.0              5.0     2.0
# 2               6.0              5.0          6.0              6.0     1.0
# 3               4.0              5.0          4.0              4.0     1.0
# 4               5.0              5.0          5.0              5.0     1.0
#
#    Customer_Type   Age  Type_Travel  Travel_Class  Travel_Distance
# 0            1.0  52.0          1.8           0.0            272.0
# 1            1.0  48.0          1.0           1.0           2200.0
# 2            1.0  43.0          2.0           0.0           1061.0
# 3            1.0  44.0          2.0           0.0            780.0
# 4            1.0  50.0          2.0           0.0           1981.0
#
# [5 rows x 21 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
trial_data.drop(columns=["Seat_Class"], axis=1, inplace=True)
test_x.drop(columns=["Seat_Class"], axis=1, inplace=True)

# %%
# Build random forest model
# rf_model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
# rf_model.fit(trial_data, y)

# %%
# Build 2nd random forest model
rf_model = RandomForestClassifier(n_estimators=120, max_depth=22, random_state=42)
rf_model.fit(trial_data, y)
# Out:
# RandomForestClassifier(max_depth=22, n_estimators=120, random_state=42)

# %%
# Make predictions on the test data
rf_pred = rf_model.predict(test_x)

# %%
# Convert predictions to binary labels
# Only run this if you are using random forest only. Else, skip
rf_pred = np.round(rf_pred)

# %%
predictions = pd.DataFrame({'ID': test_data['ID'], 'Overall_Experience': rf_pred.flatten().astype(int)})
#predictions.to_csv(path+'predictions2.csv', index=False)
predictions.to_csv('predictions4.csv', index=False)

# %%
print(pd.DataFrame(rf_model.feature_importances_, columns = ["Imp"], index = trial_data.columns).sort_values(by = 'Imp', ascending = False))
# Out:
#                               Imp
# Onboard_Entertainment    0.222947
# Seat_Comfort             0.133469
# Ease_of_Online_Booking   0.088368
# Online_Support           0.060689
# Legroom                  0.042390
# Customer_Type            0.039399
# Travel_Distance          0.037413
# Catering                 0.037406
# Travel_Class             0.037249
# Online_Boarding          0.037166
# Age                      0.032695
# Onboard_Service          0.030738
# Gender                   0.028577
# Cleanliness              0.026795
# CheckIn_Service          0.026290
# Type_Travel              0.025821
# Baggage_Handling         0.025600
# Arrival_Time_Convenient  0.024169
# Platform_Location        0.020468
# Onboard_Wifi_Service     0.017591
# Seat_Class               0.004759
